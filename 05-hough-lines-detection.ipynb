# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img_path = '/content/drive/My Drive/img2.png'
img = cv2.imread(img_path)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray,100,400)
minLineLength = 5
maxLineGap = 2

lines = cv2.HoughLinesP(edges,1,np.pi/180,30,minLineLength,maxLineGap)

if lines is not None:
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(img, (x1, y1), (x2, y2), (0, 255, 0), 4)

cv2_imshow(edges)
cv2_imshow( img)
# Out:
# <PIL.Image.Image image mode=L size=570x525>
# <PIL.Image.Image image mode=RGB size=570x525>
