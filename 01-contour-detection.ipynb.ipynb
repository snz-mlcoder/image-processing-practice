# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

img_path = '/content/drive/My Drive/img.png'

print("Image path:", img_path)
img = cv2.imread(img_path)

if img is None:
    print("⚠️ img not found  !")
else:
    print("Image shape:", img.shape)
    print("Image data type:", img.dtype)


    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray, 127, 255, 0)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) == 0:
        print("No contours found in the image.")
    else:
        print("Number of contours:", len(contours))

    img_contour = cv2.drawContours(img.copy(), contours, -1, (255, 255, 0), 2)
    cv2_imshow(img_contour)
# Out:
# Image path: /content/drive/My Drive/img.png
# Image shape: (1024, 1024, 3)
# Image data type: uint8
# Number of contours: 1848
# <PIL.Image.Image image mode=RGB size=1024x1024>
